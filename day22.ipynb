# %%
#Using the Google Geocoding API with a Database and 
#Visualizing data on Google Map
#
#In this project, we are using the Google geocoding API
#to clean up some user-entered geographic locations of 
#university names and then placing the data on a Google
#Map.
#
#You should install the SQLite browser to view and modify 
#the databases from:
#
#http://sqlitebrowser.org/
#
#The first problem to solve is that the Google geocoding
#API is rate limited to 2500 requests per day.  So if you have
#a lot of data you might need to stop and restart the lookup
#process several times.  So we break the problem into two
#phases.  
#
#In the first phase we take our input data in the file
#(where.data) and read it one line at a time, and retreive the
#geocoded response and store it in a database (geodata.sqlite).
#Before we use the geocoding API, we simply check to see if
#we already have the data for that particular line of input.
#
#You can re-start the process at any time by removing the file
#geodata.sqlite
#
#Run the geoload.py program.   This program will read the input
#lines in where.data and for each line check to see if it is already
#in the database and if we don't have the data for the location,
#call the geocoding API to retrieve the data and store it in 
#the database.
#
#As of December 2016, the Google Geocoding API requires an API
#key.   To complete this assignment, you can use a subset of that data
#which is available at:
#
#http://python-data.dr-chuck.net/geojson
#
#This URL only has a subset of the data but it has no rate limit so 
#it is good for testing.
#
#For example:
#
#http://python-data.dr-chuck.net/geojson?address=Northeastern+University
#
#If you get an API from Google, you can use the original URL:
#
#http://maps.googleapis.com/maps/api/geocode/json?address=Monash+University
#
#Here is a sample run after there is already some data in the 
#database:
#
#Mac: python geoload.py
#Win: geoload.py
#
#Found in database  Northeastern University
#
#Found in database  University of Hong Kong, Illinois Institute of Technology, Bradley University
#
#Found in database  Technion
#
#Found in database  Viswakarma Institute, Pune, India
#
#Found in database  UMD
#
#Found in database  Tufts University
#
#Resolving Monash University
#Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Monash+University
#Retrieved 2063 characters {    "results" : [  
#{u'status': u'OK', u'results': ... }
#
#Resolving Kokshetau Institute of Economics and Management
#Retrieving http://maps.googleapis.com/maps/api/geocode/json?sensor=false&address=Kokshetau+Institute+of+Economics+and+Management
#Retrieved 1749 characters {    "results" : [  
#{u'status': u'OK', u'results': ... }
#
#The first five locations are already in the database and so they 
#are skipped.  The program scans to the point where it finds un-retrieved
#locations and starts retrieving them.
#
#The geoload.py can be stopped at any time, and there is a counter 
#that you can use to limit the number of calls to the geocoding
#API for each run.
#
#Once you have some data loaded into geodata.sqlite, you can 
#visualize the data using the (geodump.py) program.  This
#program reads the database and writes tile file (where.js)
#with the location, latitude, and longitude in the form of
#executable JavaScript code.   
#
#A run of the geodump.py program is as follows:
#
#Mac: python geodump.py
#Win: geodump.py
#
#Northeastern University, 360 Huntington Avenue, Boston, MA 02115, USA 42.3396998 -71.08975
#Bradley University, 1501 West Bradley Avenue, Peoria, IL 61625, USA 40.6963857 -89.6160811
#...
#Technion, Viazman 87, Kesalsaba, 32000, Israel 32.7775 35.0216667
#Monash University Clayton Campus, Wellington Road, Clayton VIC 3800, Australia -37.9152113 145.134682
#Kokshetau, Kazakhstan 53.2833333 69.3833333
#...
#12 records written to where.js
#Open where.html to view the data in a browser

#The file (where.html) consists of HTML and JavaScript to visualize 
#a Google Map.  It reads the most recent data in where.js to get 
#the data to be visualized.  Here is the format of the where.js file:
#
#myData = [
#[42.3396998,-71.08975, 'Northeastern University, 360 Huntington Avenue, Boston, MA 02115, USA'],
#[40.6963857,-89.6160811, 'Bradley University, 1501 West Bradley Avenue, Peoria, IL 61625, USA'],
#[32.7775,35.0216667, 'Technion, Viazman 87, Kesalsaba, 32000, Israel'],
#   ...
#];
#
#This is a JavaScript list of lists.  The syntax for JavaScript 
#list constants is very similar to Python so the syntax should 
#be familiar to you.
#
#Simply open where.html in a browser to see the locations.  You 
#can hover over each map pin to find the location that the 
#gecoding API returned for the user-entered input.  If you 
#cannot see any data when you open the where.html file, you might 
#want to check the JavaScript or developer console for your browser.

# %%
# assignment (parsing google map and visualize data)

# 1.geoload

#a.import
import ssl
import json
import urllib.request, urllib.error, urllib.parse
import sqlite3
import http
import sys
import time
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE
#b.api
api_key = 'AIzaSyDS9ADEfzGK_vvZbiWKLU_Bh5-FcOvyUV4'

if api_key is False:
    serviceurl = 'http://py4e-data.dr-chuck.net/json?'
else :
    serviceurl = 'https://maps.googleapis.com/maps/api/geocode/json?'
#c.data base connection
conn = sqlite3.connect('geodata.sqlite')
cur = conn.cursor()
#d.create table
cur.execute('CREATE TABLE IF NOT EXISTS Locations (address TEXT, geodata INTEGER)')
#e.ctx
#f.open txt and loop begin
fh = open('where.data')         
count = 0
for line in fh:
#g.set limit
    if count > 100:
        print('Retrieved 100 locations, restart to retrieve more')
        break
#h.lock geodata
    address = line.strip()
    cur.execute('SELECT geodata FROM Locations WHERE address = ?', (memoryview(address.encode()), ))
#i.get data
    try:
        data = cur.fetchone()[0]
        print('Found in database ', address)
        continue
    except:
        pass
#* try to find the address that have existed in the db
#j.make a dict and inserted key and value
    parms = dict()
    parms['address'] = address
    if api_key is not False:
            parms['key'] = api_key
    url = serviceurl + urllib.parse.urlencode(parms)
#k.encode the api to make a url
#l.access the url and get the data before transforming it to json
    connection = urllib.request.urlopen(url, context = ctx)
    data = connection.read().decode()
    print('Retrieved', len(data), 'characters', data[:20].replace('\n',''))
    count = count + 1
#m. search through json and enter insert the data
    try:
        js = json.loads(data)
    except:
        print(data)
        continue
    
    if 'status' not in js or (js['status'] != 'OK' and js['status'] != 'ZERO_RESULTS') :
        print('=== Failure To Retrieve ===')
        print(data)
        break
    cur.execute('''INSERT INTO Locations (address, geodata) VALUES (?, ?)''',
               (memoryview(address.encode()), memoryview(data.encode())))
    conn.commit()
    if count % 10 == 0:
        print('Pausing for a bit...')
        time.sleep(5)
#n. commit the data and then set the sleeping interval
print('Run geodump.py to read the data from the database so you can\
      visualize it on a map.')
# Out:
# data {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "30",
#                "short_name" : "30",
#                "types" : [ "street_number" ]
#             },
#             {
#                "long_name" : "aleja Adama Mickiewicza",
#                "short_name" : "aleja Adama Mickiewicza",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Krowodrza",
#                "short_name" : "Krowodrza",
#                "types" : [ "political", "sublocality", "sublocality_level_1" ]
#             },
#             {
#                "long_name" : "Kraków",
#                "short_name" : "Kraków",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Kraków",
#                "short_name" : "Kraków",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "małopolskie",
#                "short_name" : "małopolskie",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "Poland",
#                "short_name" : "PL",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "30-059",
#                "short_name" : "30-059",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "aleja Adama Mickiewicza 30, 30-059 Kraków, Poland",
#          "geometry" : {
#             "location" : {
#                "lat" : 50.06688579999999,
#                "lng" : 19.9136192
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 50.0682347802915,
#                   "lng" : 19.9149681802915
#                },
#                "southwest" : {
#                   "lat" : 50.0655368197085,
#                   "lng" : 19.9122702197085
#                }
#             }
#          },
#          "place_id" : "ChIJIZu1VqdbFkcR0RezIbqNDLI",
#          "plus_code" : {
#             "compound_code" : "3W87+QC Kraków, Poland",
#             "global_code" : "9F2X3W87+QC"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Retrieved 2315 characters {   "results" : [
# data {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "Warszawa",
#                "short_name" : "Warszawa",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Poland",
#                "short_name" : "PL",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "00-068",
#                "short_name" : "00-068",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "Krakowskie Przedmieście 5, 00-068 Warszawa, Poland",
#          "geometry" : {
#             "location" : {
#                "lat" : 52.2394019,
#                "lng" : 21.0150792
#             },
#             "location_type" : "GEOMETRIC_CENTER",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 52.2407508802915,
#                   "lng" : 21.0164281802915
#                },
#                "southwest" : {
#                   "lat" : 52.2380529197085,
#                   "lng" : 21.0137302197085
#                }
#             }
#          },
#          "place_id" : "ChIJLzAMf2DMHkcR5qCqT76Dq9M",
#          "plus_code" : {
#             "compound_code" : "62Q8+Q2 Warsaw, Poland",
#             "global_code" : "9G4362Q8+Q2"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Retrieved 1435 characters {   "results" : [
# data {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "11835",
#                "short_name" : "11835",
#                "types" : [ "postal_code" ]
#             },
#             {
#                "long_name" : "Egypt",
#                "short_name" : "EG",
#                "types" : [ "country", "political" ]
#             }
#          ],
#          "formatted_address" : "AUC Avenue، 11835, Egypt",
#          "geometry" : {
#             "location" : {
#                "lat" : 30.018923,
#                "lng" : 31.499674
#             },
#             "location_type" : "GEOMETRIC_CENTER",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 30.0202719802915,
#                   "lng" : 31.5010229802915
#                },
#                "southwest" : {
#                   "lat" : 30.0175740197085,
#                   "lng" : 31.4983250197085
#                }
#             }
#          },
#          "place_id" : "ChIJ0Rb5-FoiWBQRxwXiQTG_6HU",
#          "plus_code" : {
#             "compound_code" : "2F9X+HV New Cairo City, Egypt",
#             "global_code" : "8G2H2F9X+HV"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Retrieved 1246 characters {   "results" : [
# data {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "Tempe",
#                "short_name" : "Tempe",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Maricopa County",
#                "short_name" : "Maricopa County",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "Arizona",
#                "short_name" : "AZ",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "United States",
#                "short_name" : "US",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "85281",
#                "short_name" : "85281",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "Tempe, AZ 85281, USA",
#          "geometry" : {
#             "location" : {
#                "lat" : 33.4242399,
#                "lng" : -111.9280527
#             },
#             "location_type" : "GEOMETRIC_CENTER",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 33.42558888029149,
#                   "lng" : -111.9267037197085
#                },
#                "southwest" : {
#                   "lat" : 33.42289091970849,
#                   "lng" : -111.9294016802915
#                }
#             }
#          },
#          "place_id" : "ChIJD1QzO9sIK4cRMzA8R39xbmY",
#          "plus_code" : {
#             "compound_code" : "C3FC+MQ Tempe, Arizona, United States",
#             "global_code" : "855CC3FC+MQ"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Retrieved 1802 characters {   "results" : [
# data {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "300",
#                "short_name" : "300",
#                "types" : [ "premise" ]
#             },
#             {
#                "long_name" : "2500",
#                "short_name" : "2500",
#                "types" : [ "street_number" ]
#             },
#             {
#                "long_name" : "Daniells Bridge Road",
#                "short_name" : "Daniells Bridge Rd",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Athens",
#                "short_name" : "Athens",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Oconee County",
#                "short_name" : "Oconee County",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "Georgia",
#                "short_name" : "GA",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "United States",
#                "short_name" : "US",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "30606",
#                "short_name" : "30606",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "300, 2500 Daniells Bridge Rd, Athens, GA 30606, USA",
#          "geometry" : {
#             "location" : {
#                "lat" : 33.9094132,
#                "lng" : -83.4603953
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 33.9107621802915,
#                   "lng" : -83.45904631970849
#                },
#                "southwest" : {
#                   "lat" : 33.9080642197085,
#                   "lng" : -83.46174428029151
#                }
#             }
#          },
#          "place_id" : "ChIJX-nQnzZy9ogRR_2GUv9bDM0",
#          "plus_code" : {
#             "compound_code" : "WG5Q+QR Barber Creek Estates",
#             "global_code" : "865RWG5Q+QR"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Retrieved 2271 characters {   "results" : [
# data {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "Pilani",
#                "short_name" : "Pilani",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Jhunjhunu",
#                "short_name" : "Jhunjhunu",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "Rajasthan",
#                "short_name" : "RJ",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "India",
#                "short_name" : "IN",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "333031",
#                "short_name" : "333031",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "Pilani, Rajasthan 333031, India",
#          "geometry" : {
#             "location" : {
#                "lat" : 28.3588163,
#                "lng" : 75.58802039999999
#             },
#             "location_type" : "GEOMETRIC_CENTER",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 28.3601652802915,
#                   "lng" : 75.5893693802915
#                },
#                "southwest" : {
#                   "lat" : 28.3574673197085,
#                   "lng" : 75.58667141970848
#                }
#             }
#          },
#          "place_id" : "ChIJdUU-9GQZEzkRTYjPVAjTuh8",
#          "plus_code" : {
#             "compound_code" : "9H5Q+G6 Pilani, Rajasthan, India",
#             "global_code" : "7JWQ9H5Q+G6"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Retrieved 1794 characters {   "results" : [
# data {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "Ilishan-Remo",
#                "short_name" : "Ilishan-Remo",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Ikenne",
#                "short_name" : "Ikenne",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "Ìpínlẹ̀ Ògùn",
#                "short_name" : "OG",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "Nigeria",
#                "short_name" : "NG",
#                "types" : [ "country", "political" ]
#             }
#          ],
#          "formatted_address" : "Ilishan-Remo, Nigeria",
#          "geometry" : {
#             "location" : {
#                "lat" : 6.8946472,
#                "lng" : 3.7174267
#             },
#             "location_type" : "GEOMETRIC_CENTER",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 6.895996180291502,
#                   "lng" : 3.718775680291503
#                },
#                "southwest" : {
#                   "lat" : 6.893298219708497,
#                   "lng" : 3.716077719708498
#                }
#             }
#          },
#          "place_id" : "ChIJw07lORbYOxARUn42yKi0KZE",
#          "plus_code" : {
#             "compound_code" : "VPV8+VX Ilishan-Remo, Nigeria",
#             "global_code" : "6FR5VPV8+VX"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Retrieved 1635 characters {   "results" : [
# data {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "Ajagara",
#                "short_name" : "Ajagara",
#                "types" : [ "neighborhood", "political" ]
#             },
#             {
#                "long_name" : "Varanasi",
#                "short_name" : "Varanasi",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Varanasi",
#                "short_name" : "Varanasi",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "Uttar Pradesh",
#                "short_name" : "UP",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "India",
#                "short_name" : "IN",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "221005",
#                "short_name" : "221005",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "Ajagara, Varanasi, Uttar Pradesh 221005, India",
#          "geometry" : {
#             "location" : {
#                "lat" : 25.2677203,
#                "lng" : 82.99125819999999
#             },
#             "location_type" : "GEOMETRIC_CENTER",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 25.2690692802915,
#                   "lng" : 82.99260718029149
#                },
#                "southwest" : {
#                   "lat" : 25.2663713197085,
#                   "lng" : 82.98990921970848
#                }
#             }
#          },
#          "place_id" : "ChIJVx24kCkyjjkRJ4c60-w9fBg",
#          "plus_code" : {
#             "compound_code" : "7X9R+3G Varanasi, Uttar Pradesh, India",
#             "global_code" : "7MQ47X9R+3G"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Retrieved 1989 characters {   "results" : [
# data {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "Gnana Bharathi Campus",
#                "short_name" : "Gnana Bharathi Campus",
#                "types" : [ "premise" ]
#             },
#             {
#                "long_name" : "Gnana Bharathi Main Road",
#                "short_name" : "Gnana Bharathi Main Rd",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Teachers Colony",
#                "short_name" : "Teachers Colony",
#                "types" : [ "political", "sublocality", "sublocality_level_2" ]
#             },
#             {
#                "long_name" : "Nagarbhavi",
#                "short_name" : "Nagarbhavi",
#                "types" : [ "political", "sublocality", "sublocality_level_1" ]
#             },
#             {
#                "long_name" : "Bengaluru",
#                "short_name" : "Bengaluru",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Bangalore Urban",
#                "short_name" : "Bangalore Urban",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "Karnataka",
#                "short_name" : "KA",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "India",
#                "short_name" : "IN",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "560056",
#                "short_name" : "560056",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "Gnana Bharathi Campus, Gnana Bharathi Main Rd, Teachers Colony, Nagarbhavi, Bengaluru, Karnataka 560056, India",
#          "geometry" : {
#             "location" : {
#                "lat" : 12.9527314,
#                "lng" : 77.5157387
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 12.9540803802915,
#                   "lng" : 77.51708768029151
#                },
#                "southwest" : {
#                   "lat" : 12.9513824197085,
#                   "lng" : 77.5143897197085
#                }
#             }
#          },
#          "place_id" : "ChIJc64iWn0-rjsRqZlBnbHY75k",
#          "plus_code" : {
#             "compound_code" : "XG38+37 Bengaluru, Karnataka, India",
#             "global_code" : "7J4VXG38+37"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Retrieved 2634 characters {   "results" : [
# data {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "1301",
#                "short_name" : "1301",
#                "types" : [ "street_number" ]
#             },
#             {
#                "long_name" : "South University Parks Drive",
#                "short_name" : "S University Parks Dr",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Waco",
#                "short_name" : "Waco",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "McLennan County",
#                "short_name" : "McLennan County",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "Texas",
#                "short_name" : "TX",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "United States",
#                "short_name" : "US",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "76706",
#                "short_name" : "76706",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "1301 S University Parks Dr, Waco, TX 76706, USA",
#          "geometry" : {
#             "location" : {
#                "lat" : 31.5497007,
#                "lng" : -97.1143046
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 31.5510496802915,
#                   "lng" : -97.11295561970849
#                },
#                "southwest" : {
#                   "lat" : 31.5483517197085,
#                   "lng" : -97.11565358029151
#                }
#             }
#          },
#          "place_id" : "ChIJkebHSWqCT4YR3df3-lbTamM",
#          "plus_code" : {
#             "compound_code" : "GVXP+V7 Waco, Texas, United States",
#             "global_code" : "8634GVXP+V7"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Retrieved 2141 characters {   "results" : [
# Pausing for a bit...
# data {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "19",
#                "short_name" : "19",
#                "types" : [ "street_number" ]
#             },
#             {
#                "long_name" : "Xinjiekou Outer Street",
#                "short_name" : "Xinjiekou Outer St",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "BeiTaiPingZhuang",
#                "short_name" : "BeiTaiPingZhuang",
#                "types" : [ "neighborhood", "political" ]
#             },
#             {
#                "long_name" : "Haidian Qu",
#                "short_name" : "Haidian Qu",
#                "types" : [ "political", "sublocality", "sublocality_level_1" ]
#             },
#             {
#                "long_name" : "Beijing Shi",
#                "short_name" : "Beijing Shi",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "China",
#                "short_name" : "CN",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "100875",
#                "short_name" : "100875",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "19 Xinjiekou Outer St, BeiTaiPingZhuang, Haidian Qu, Beijing Shi, China, 100875",
#          "geometry" : {
#             "location" : {
#                "lat" : 39.9619537,
#                "lng" : 116.3662615
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 39.96330268029149,
#                   "lng" : 116.3676104802915
#                },
#                "southwest" : {
#                   "lat" : 39.96060471970849,
#                   "lng" : 116.3649125197085
#                }
#             }
#          },
#          "place_id" : "ChIJxfN4FJpT8DURc9euvSu2ob0",
#          "plus_code" : {
#             "compound_code" : "X968+QG Haidian, Beijing, China",
#             "global_code" : "8PFRX968+QG"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Retrieved 2191 characters {   "results" : [
# data {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "4",
#                "short_name" : "4",
#                "types" : [ "street_number" ]
#             },
#             {
#                "long_name" : "Prospekt Nezavisimosti",
#                "short_name" : "Prospekt Nezavisimosti",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Maskoŭski rajon",
#                "short_name" : "Maskoŭski rajon",
#                "types" : [ "political", "sublocality", "sublocality_level_1" ]
#             },
#             {
#                "long_name" : "Minsk",
#                "short_name" : "Minsk",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Belarus",
#                "short_name" : "BY",
#                "types" : [ "country", "political" ]
#             }
#          ],
#          "formatted_address" : "Prospekt Nezavisimosti 4, Minsk, Belarus",
#          "geometry" : {
#             "location" : {
#                "lat" : 53.8938988,
#                "lng" : 27.5460609
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 53.89524778029149,
#                   "lng" : 27.5474098802915
#                },
#                "southwest" : {
#                   "lat" : 53.8925498197085,
#                   "lng" : 27.5447119197085
#                }
#             }
#          },
#          "place_id" : "ChIJVUqIm-fP20YRj5roNMigAqg",
#          "plus_code" : {
#             "compound_code" : "VGVW+HC Minsk, Belarus",
#             "global_code" : "9G59VGVW+HC"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       },
#       {
#          "address_components" : [
#             {
#                "long_name" : "Belarus",
#                "short_name" : "BY",
#                "types" : [ "country", "political" ]
#             }
#          ],
#          "formatted_address" : "Рабкоровская 17, Минск, 220007, Belarus",
#          "geometry" : {
#             "location" : {
#                "lat" : 53.886864,
#                "lng" : 27.5418905
#             },
#             "location_type" : "GEOMETRIC_CENTER",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 53.8882129802915,
#                   "lng" : 27.5432394802915
#                },
#                "southwest" : {
#                   "lat" : 53.8855150197085,
#                   "lng" : 27.5405415197085
#                }
#             }
#          },
#          "place_id" : "ChIJs4tH49_P20YRMW0pE5A376M",
#          "plus_code" : {
#             "compound_code" : "VGPR+PQ Minsk, Belarus",
#             "global_code" : "9G59VGPR+PQ"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Retrieved 2849 characters {   "results" : [
# data {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "1",
#                "short_name" : "1",
#                "types" : [ "street_number" ]
#             },
#             {
#                "long_name" : "Studentski trg",
#                "short_name" : "Studentski trg",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Stari Grad",
#                "short_name" : "Stari Grad",
#                "types" : [ "political", "sublocality", "sublocality_level_1" ]
#             },
#             {
#                "long_name" : "Beograd",
#                "short_name" : "BG",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Grad Beograd",
#                "short_name" : "Grad Beograd",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "Serbia",
#                "short_name" : "RS",
#                "types" : [ "country", "political" ]
#             }
#          ],
#          "formatted_address" : "Studentski trg 1, Beograd, Serbia",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.8184339,
#                "lng" : 20.4575676
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.8197828802915,
#                   "lng" : 20.4589165802915
#                },
#                "southwest" : {
#                   "lat" : 44.8170849197085,
#                   "lng" : 20.45621861970849
#                }
#             }
#          },
#          "place_id" : "ChIJv_ehNbN6WkcROV6HX6xX5Vc",
#          "plus_code" : {
#             "compound_code" : "RF95+92 Belgrade, Serbia",
#             "global_code" : "8GP2RF95+92"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Retrieved 1945 characters {   "results" : [
# data {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "700",
#                "short_name" : "700",
#                "types" : [ "street_number" ]
#             },
#             {
#                "long_name" : "College Street",
#                "short_name" : "College St",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Beloit",
#                "short_name" : "Beloit",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Rock County",
#                "short_name" : "Rock County",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "Wisconsin",
#                "short_name" : "WI",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "United States",
#                "short_name" : "US",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "53511",
#                "short_name" : "53511",
#                "types" : [ "postal_code" ]
#             },
#             {
#                "long_name" : "5509",
#                "short_name" : "5509",
#                "types" : [ "postal_code_suffix" ]
#             }
#          ],
#          "formatted_address" : "700 College St, Beloit, WI 53511, USA",
#          "geometry" : {
#             "location" : {
#                "lat" : 42.5030333,
#                "lng" : -89.0309048
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 42.50438228029149,
#                   "lng" : -89.02955581970851
#                },
#                "southwest" : {
#                   "lat" : 42.5016843197085,
#                   "lng" : -89.03225378029151
#                }
#             }
#          },
#          "place_id" : "ChIJBchm5CahCIgRLbbEDEzoELY",
#          "plus_code" : {
#             "compound_code" : "GX39+6J Beloit, Wisconsin, United States",
#             "global_code" : "86JGGX39+6J"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Retrieved 2265 characters {   "results" : [
# data {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "4",
#                "short_name" : "4",
#                "types" : [ "street_number" ]
#             },
#             {
#                "long_name" : "Prospekt Nezavisimosti",
#                "short_name" : "Prospekt Nezavisimosti",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Maskoŭski rajon",
#                "short_name" : "Maskoŭski rajon",
#                "types" : [ "political", "sublocality", "sublocality_level_1" ]
#             },
#             {
#                "long_name" : "Minsk",
#                "short_name" : "Minsk",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Belarus",
#                "short_name" : "BY",
#                "types" : [ "country", "political" ]
#             }
#          ],
#          "formatted_address" : "Prospekt Nezavisimosti 4, Minsk, Belarus",
#          "geometry" : {
#             "location" : {
#                "lat" : 53.8938988,
#                "lng" : 27.5460609
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 53.89524778029149,
#                   "lng" : 27.5474098802915
#                },
#                "southwest" : {
#                   "lat" : 53.8925498197085,
#                   "lng" : 27.5447119197085
#                }
#             }
#          },
#          "place_id" : "ChIJVUqIm-fP20YRj5roNMigAqg",
#          "plus_code" : {
#             "compound_code" : "VGVW+HC Minsk, Belarus",
#             "global_code" : "9G59VGVW+HC"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       },
#       {
#          "address_components" : [
#             {
#                "long_name" : "Belarus",
#                "short_name" : "BY",
#                "types" : [ "country", "political" ]
#             }
#          ],
#          "formatted_address" : "Рабкоровская 17, Минск, 220007, Belarus",
#          "geometry" : {
#             "location" : {
#                "lat" : 53.886864,
#                "lng" : 27.5418905
#             },
#             "location_type" : "GEOMETRIC_CENTER",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 53.8882129802915,
#                   "lng" : 27.5432394802915
#                },
#                "southwest" : {
#                   "lat" : 53.8855150197085,
#                   "lng" : 27.5405415197085
#                }
#             }
#          },
#          "place_id" : "ChIJs4tH49_P20YRMW0pE5A376M",
#          "plus_code" : {
#             "compound_code" : "VGPR+PQ Minsk, Belarus",
#             "global_code" : "9G59VGPR+PQ"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Retrieved 2849 characters {   "results" : [
# data {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "1",
#                "short_name" : "1",
#                "types" : [ "street_number" ]
#             },
#             {
#                "long_name" : "שד' בן-גוריון",
#                "short_name" : "שד' בן-גוריון",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "באר שבע",
#                "short_name" : "ב\"ש",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "באר שבע",
#                "short_name" : "באר שבע",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "מחוז הדרום",
#                "short_name" : "מחוז הדרום",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "Israel",
#                "short_name" : "IL",
#                "types" : [ "country", "political" ]
#             }
#          ],
#          "formatted_address" : "שד' בן-גוריון 1, באר שבע, Israel",
#          "geometry" : {
#             "location" : {
#                "lat" : 31.262218,
#                "lng" : 34.801461
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 31.2635669802915,
#                   "lng" : 34.8028099802915
#                },
#                "southwest" : {
#                   "lat" : 31.2608690197085,
#                   "lng" : 34.8001120197085
#                }
#             }
#          },
#          "place_id" : "ChIJG8cBLl9mAhURk7hAwbBNyhU",
#          "plus_code" : {
#             "compound_code" : "7R62+VH Be'er Sheva, Israel",
#             "global_code" : "8G3P7R62+VH"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Retrieved 1927 characters {   "results" : [
# data {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "Tiruchirappalli",
#                "short_name" : "Tiruchirappalli",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Tamil Nadu",
#                "short_name" : "TN",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "India",
#                "short_name" : "IN",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "620024",
#                "short_name" : "620024",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "Palkalaiperur, Tiruchirappalli, Tamil Nadu 620024, India",
#          "geometry" : {
#             "location" : {
#                "lat" : 10.6779085,
#                "lng" : 78.74454879999999
#             },
#             "location_type" : "GEOMETRIC_CENTER",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 10.6792574802915,
#                   "lng" : 78.7458977802915
#                },
#                "southwest" : {
#                   "lat" : 10.6765595197085,
#                   "lng" : 78.74319981970848
#                }
#             }
#          },
#          "partial_match" : true,
#          "place_id" : "ChIJP1IUwk2JqjsRc3y97ndv37A",
#          "plus_code" : {
#             "compound_code" : "MPHV+5R Sooriyur, Tamil Nadu, India",
#             "global_code" : "7J2WMPHV+5R"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Retrieved 1688 characters {   "results" : [
# data {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "Boston",
#                "short_name" : "Boston",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Fenway/Kenmore",
#                "short_name" : "Fenway/Kenmore",
#                "types" : [ "neighborhood", "political" ]
#             },
#             {
#                "long_name" : "Suffolk County",
#                "short_name" : "Suffolk County",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "Massachusetts",
#                "short_name" : "MA",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "United States",
#                "short_name" : "US",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "02215",
#                "short_name" : "02215",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "Boston, MA 02215, USA",
#          "geometry" : {
#             "location" : {
#                "lat" : 42.3504997,
#                "lng" : -71.1053991
#             },
#             "location_type" : "GEOMETRIC_CENTER",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 42.3518486802915,
#                   "lng" : -71.1040501197085
#                },
#                "southwest" : {
#                   "lat" : 42.3491507197085,
#                   "lng" : -71.10674808029151
#                }
#             }
#          },
#          "place_id" : "ChIJFzjlY_B544kRyL6j4ABuNCs",
#          "plus_code" : {
#             "compound_code" : "9V2V+5R Boston, Massachusetts, United States",
#             "global_code" : "87JC9V2V+5R"
#          },
#          "types" : [ "establishment", "health", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Retrieved 2003 characters {   "results" : [
# data {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "San Luis Obispo",
#                "short_name" : "San Luis Obispo",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "San Luis Obispo County",
#                "short_name" : "San Luis Obispo County",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "California",
#                "short_name" : "CA",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "United States",
#                "short_name" : "US",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "93407",
#                "short_name" : "93407",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "San Luis Obispo, CA 93407, USA",
#          "geometry" : {
#             "location" : {
#                "lat" : 35.3050053,
#                "lng" : -120.6624942
#             },
#             "location_type" : "GEOMETRIC_CENTER",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 35.3063542802915,
#                   "lng" : -120.6611452197085
#                },
#                "southwest" : {
#                   "lat" : 35.3036563197085,
#                   "lng" : -120.6638431802915
#                }
#             }
#          },
#          "place_id" : "ChIJUTVMBbTx7IARA5HZKYq0s5g",
#          "plus_code" : {
#             "compound_code" : "884Q+22 San Luis Obispo, California, United States",
#             "global_code" : "847X884Q+22"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Retrieved 1860 characters {   "results" : [
# data {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "5500",
#                "short_name" : "5500",
#                "types" : [ "street_number" ]
#             },
#             {
#                "long_name" : "University Parkway",
#                "short_name" : "University Pkwy",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "San Bernardino",
#                "short_name" : "San Bernardino",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "San Bernardino County",
#                "short_name" : "San Bernardino County",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "California",
#                "short_name" : "CA",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "United States",
#                "short_name" : "US",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "92407",
#                "short_name" : "92407",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "5500 University Pkwy, San Bernardino, CA 92407, USA",
#          "geometry" : {
#             "location" : {
#                "lat" : 34.1821786,
#                "lng" : -117.3235324
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 34.1835275802915,
#                   "lng" : -117.3221834197085
#                },
#                "southwest" : {
#                   "lat" : 34.1808296197085,
#                   "lng" : -117.3248813802915
#                }
#             }
#          },
#          "place_id" : "ChIJ18hFFptRw4ARInn08NJCwfo",
#          "plus_code" : {
#             "compound_code" : "5MJG+VH San Bernardino, California, United States",
#             "global_code" : "85645MJG+VH"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Retrieved 2182 characters {   "results" : [
# Pausing for a bit...
# data {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "25",
#                "short_name" : "25",
#                "types" : [ "street_number" ]
#             },
#             {
#                "long_name" : "Paddington Green",
#                "short_name" : "Paddington Green",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "London",
#                "short_name" : "London",
#                "types" : [ "postal_town" ]
#             },
#             {
#                "long_name" : "Greater London",
#                "short_name" : "Greater London",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "England",
#                "short_name" : "England",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "United Kingdom",
#                "short_name" : "GB",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "W2 1NB",
#                "short_name" : "W2 1NB",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "25 Paddington Green, London W2 1NB, UK",
#          "geometry" : {
#             "location" : {
#                "lat" : 51.5210038,
#                "lng" : -0.1746353
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 51.52235278029149,
#                   "lng" : -0.173286319708498
#                },
#                "southwest" : {
#                   "lat" : 51.51965481970849,
#                   "lng" : -0.175984280291502
#                }
#             }
#          },
#          "place_id" : "ChIJ21PcE7IadkgRCZeigjmpxI8",
#          "plus_code" : {
#             "compound_code" : "GRCG+C4 Paddington, London, United Kingdom",
#             "global_code" : "9C3XGRCG+C4"
#          },
#          "types" : [ "establishment", "point_of_interest", "school", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Retrieved 2132 characters {   "results" : [
# data {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "New York",
#                "short_name" : "New York",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "New York",
#                "short_name" : "NY",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "United States",
#                "short_name" : "US",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "10027",
#                "short_name" : "10027",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "116th St & Broadway, New York, NY 10027, United States",
#          "geometry" : {
#             "location" : {
#                "lat" : 40.8075355,
#                "lng" : -73.9625727
#             },
#             "location_type" : "GEOMETRIC_CENTER",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 40.8088844802915,
#                   "lng" : -73.96122371970849
#                },
#                "southwest" : {
#                   "lat" : 40.8061865197085,
#                   "lng" : -73.96392168029151
#                }
#             }
#          },
#          "place_id" : "ChIJyQ3Tlj72wokRUCflR_kzeVc",
#          "plus_code" : {
#             "compound_code" : "R25P+2X New York, United States",
#             "global_code" : "87G8R25P+2X"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Retrieved 1636 characters {   "results" : [
# data {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "College Road",
#                "short_name" : "College Rd",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Wharley End",
#                "short_name" : "Wharley End",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Bedford",
#                "short_name" : "Bedford",
#                "types" : [ "postal_town" ]
#             },
#             {
#                "long_name" : "Central Bedfordshire",
#                "short_name" : "Central Bedfordshire",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "England",
#                "short_name" : "England",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "United Kingdom",
#                "short_name" : "GB",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "MK43 0AL",
#                "short_name" : "MK43 0AL",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "College Rd, Wharley End, Bedford MK43 0AL, UK",
#          "geometry" : {
#             "location" : {
#                "lat" : 52.0741818,
#                "lng" : -0.6278123
#             },
#             "location_type" : "GEOMETRIC_CENTER",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 52.0755307802915,
#                   "lng" : -0.626463319708498
#                },
#                "southwest" : {
#                   "lat" : 52.0728328197085,
#                   "lng" : -0.6291612802915021
#                }
#             }
#          },
#          "place_id" : "ChIJ6_rISE2sd0gRl86SveYDyUQ",
#          "plus_code" : {
#             "compound_code" : "39FC+MV Wharley End, United Kingdom",
#             "global_code" : "9C4X39FC+MV"
# ...
#             {
#                "long_name" : "Professor CR Rao Road",
#                "short_name" : "Professor CR Rao Rd",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Gachibowli",
#                "short_name" : "Gachibowli",
#                "types" : [ "political", "sublocality", "sublocality_level_1" ]
#             },
#             {
#                "long_name" : "Hyderabad",
#                "short_name" : "Hyderabad",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Ranga Reddy",
#                "short_name" : "R.R. District",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "Telangana",
#                "short_name" : "Telangana",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "India",
#                "short_name" : "IN",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "500032",
#                "short_name" : "500032",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "DLF Building, Professor CR Rao Rd, Gachibowli, Hyderabad, Telangana 500032, India",
#          "geometry" : {
#             "location" : {
#                "lat" : 17.4452358,
#                "lng" : 78.3492765
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 17.4465847802915,
#                   "lng" : 78.35062548029151
#                },
#                "southwest" : {
#                   "lat" : 17.4438868197085,
#                   "lng" : 78.34792751970849
#                }
#             }
#          },
#          "place_id" : "ChIJK_h_8QMKzjsRlrTemJvoAp0",
#          "plus_code" : {
#             "compound_code" : "C8WX+3P Hyderabad, Telangana, India",
#             "global_code" : "7J9WC8WX+3P"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Retrieved 2378 characters {   "results" : [
# data {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "Kalyanpur",
#                "short_name" : "Kalyanpur",
#                "types" : [ "political", "sublocality", "sublocality_level_1" ]
#             },
#             {
#                "long_name" : "Kanpur",
#                "short_name" : "Kanpur",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Kanpur Nagar",
#                "short_name" : "Kanpur Nagar",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "Uttar Pradesh",
#                "short_name" : "UP",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "India",
#                "short_name" : "IN",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "208016",
#                "short_name" : "208016",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "Kalyanpur, Kanpur, Uttar Pradesh 208016, India",
#          "geometry" : {
#             "location" : {
#                "lat" : 26.5123388,
#                "lng" : 80.2329
#             },
#             "location_type" : "GEOMETRIC_CENTER",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 26.5136877802915,
#                   "lng" : 80.23424898029151
#                },
#                "southwest" : {
#                   "lat" : 26.5109898197085,
#                   "lng" : 80.23155101970849
#                }
#             }
#          },
#          "place_id" : "ChIJcb6oxAE3nDkRNoTDq4Do-zo",
#          "plus_code" : {
#             "compound_code" : "G66M+W5 Kanpur, Uttar Pradesh, India",
#             "global_code" : "7MR2G66M+W5"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Retrieved 2007 characters {   "results" : [
# data {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "4",
#                "short_name" : "4",
#                "types" : [ "street_number" ]
#             },
#             {
#                "long_name" : "Raja",
#                "short_name" : "Raja",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Mustamäe",
#                "short_name" : "Mustamäe",
#                "types" : [ "political", "sublocality", "sublocality_level_1" ]
#             },
#             {
#                "long_name" : "Tallinn",
#                "short_name" : "Tallinn",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Harju maakond",
#                "short_name" : "Harju maakond",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "Estonia",
#                "short_name" : "EE",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "12616",
#                "short_name" : "12616",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "Raja 4, 12616 Tallinn, Estonia",
#          "geometry" : {
#             "location" : {
#                "lat" : 59.3954769,
#                "lng" : 24.6643815
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 59.39682588029151,
#                   "lng" : 24.6657304802915
#                },
#                "southwest" : {
#                   "lat" : 59.3941279197085,
#                   "lng" : 24.6630325197085
#                }
#             }
#          },
#          "place_id" : "ChIJO0HuCqmVkkYR5ZqCELAPmU8",
#          "plus_code" : {
#             "compound_code" : "9MW7+5Q Tallinn, Harju County, Estonia",
#             "global_code" : "9GF69MW7+5Q"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Retrieved 2089 characters {   "results" : [
# data {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "107",
#                "short_name" : "107",
#                "types" : [ "street_number" ]
#             },
#             {
#                "long_name" : "South Indiana Avenue",
#                "short_name" : "S Indiana Ave",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Bloomington",
#                "short_name" : "Bloomington",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Monroe County",
#                "short_name" : "Monroe County",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "Indiana",
#                "short_name" : "IN",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "United States",
#                "short_name" : "US",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "47405",
#                "short_name" : "47405",
#                "types" : [ "postal_code" ]
#             },
#             {
#                "long_name" : "7000",
#                "short_name" : "7000",
#                "types" : [ "postal_code_suffix" ]
#             }
#          ],
#          "formatted_address" : "107 S Indiana Ave, Bloomington, IN 47405, USA",
#          "geometry" : {
#             "location" : {
#                "lat" : 39.1670139,
#                "lng" : -86.51855379999999
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 39.1683628802915,
#                   "lng" : -86.5172048197085
#                },
#                "southwest" : {
#                   "lat" : 39.1656649197085,
#                   "lng" : -86.5199027802915
#                }
#             }
#          },
#          "place_id" : "ChIJM62JZ8JmbIgRNtQVs4ugmTQ",
#          "plus_code" : {
#             "compound_code" : "5F8J+RH Bloomington, Perry Township, IN, United States",
#             "global_code" : "86FM5F8J+RH"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Retrieved 2312 characters {   "results" : [
# data {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "Venezia",
#                "short_name" : "Venezia",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Venezia",
#                "short_name" : "Venezia",
#                "types" : [ "administrative_area_level_3", "political" ]
#             },
#             {
#                "long_name" : "Città Metropolitana di Venezia",
#                "short_name" : "VE",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "Italy",
#                "short_name" : "IT",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "30135",
#                "short_name" : "30135",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "Santa Croce, 191, 30135 Venezia VE, Italy",
#          "geometry" : {
#             "location" : {
#                "lat" : 45.4377672,
#                "lng" : 12.321807
#             },
#             "location_type" : "GEOMETRIC_CENTER",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 45.43911618029151,
#                   "lng" : 12.3231559802915
#                },
#                "southwest" : {
#                   "lat" : 45.43641821970851,
#                   "lng" : 12.3204580197085
#                }
#             }
#          },
#          "place_id" : "ChIJtarwx8exfkcRF4gimmn1Gvw",
#          "plus_code" : {
#             "compound_code" : "C8QC+4P Venice, Metropolitan City of Venice, Italy",
#             "global_code" : "8FQJC8QC+4P"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Retrieved 1832 characters {   "results" : [
# data {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "10",
#                "short_name" : "10",
#                "types" : [ "street_number" ]
#             },
#             {
#                "long_name" : "W 35th St",
#                "short_name" : "W 35th St",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Douglas",
#                "short_name" : "Douglas",
#                "types" : [ "neighborhood", "political" ]
#             },
#             {
#                "long_name" : "Chicago",
#                "short_name" : "Chicago",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Cook County",
#                "short_name" : "Cook County",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "Illinois",
#                "short_name" : "IL",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "United States",
#                "short_name" : "US",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "60616",
#                "short_name" : "60616",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "10 W 35th St, Chicago, IL 60616, USA",
#          "geometry" : {
#             "location" : {
#                "lat" : 41.8348731,
#                "lng" : -87.6270059
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 41.8362220802915,
#                   "lng" : -87.6256569197085
#                },
#                "southwest" : {
#                   "lat" : 41.8335241197085,
#                   "lng" : -87.62835488029151
#                }
#             }
#          },
#          "place_id" : "ChIJD6jp03IsDogRGm_7Gmbky5E",
#          "plus_code" : {
#             "compound_code" : "R9MF+W5 Chicago, Illinois, United States",
#             "global_code" : "86HJR9MF+W5"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Retrieved 2268 characters {   "results" : [
# data {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "1215",
#                "short_name" : "1215",
#                "types" : [ "street_number" ]
#             },
#             {
#                "long_name" : "Houbolt Road",
#                "short_name" : "Houbolt Rd",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Joliet",
#                "short_name" : "Joliet",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Troy Township",
#                "short_name" : "Troy Township",
#                "types" : [ "administrative_area_level_3", "political" ]
#             },
#             {
#                "long_name" : "Will County",
#                "short_name" : "Will County",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "Illinois",
#                "short_name" : "IL",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "United States",
#                "short_name" : "US",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "60431",
#                "short_name" : "60431",
#                "types" : [ "postal_code" ]
#             },
#             {
#                "long_name" : "8938",
#                "short_name" : "8938",
#                "types" : [ "postal_code_suffix" ]
#             }
#          ],
#          "formatted_address" : "1215 Houbolt Rd, Joliet, IL 60431, USA",
#          "geometry" : {
#             "location" : {
#                "lat" : 41.5002857,
#                "lng" : -88.1687295
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 41.5016346802915,
#                   "lng" : -88.1673805197085
#                },
#                "southwest" : {
#                   "lat" : 41.4989367197085,
#                   "lng" : -88.17007848029151
#                }
#             }
#          },
#          "place_id" : "ChIJy1pt0PqJDogR_mV3_lytWWI",
#          "plus_code" : {
#             "compound_code" : "GR2J+4G Joliet, Illinois, United States",
#             "global_code" : "86HHGR2J+4G"
#          },
#          "types" : [ "establishment", "library", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Retrieved 2467 characters {   "results" : [
# Pausing for a bit...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-b985700cfe59> in <module>()
#      75     if count % 10 == 0:
#      76         print('Pausing for a bit...')
# ---> 77         time.sleep(5)
#      78 #n. commit the data and then set the sleeping interval
#      79 print('Run geodump.py to read the data from the database so you can      visualize it on a map.')
#
# KeyboardInterrupt:

# %%
fh = open("where.data")
print(fh)
# Out:
# <_io.TextIOWrapper name='where.data' mode='r' encoding='UTF-8'>

# %%
# import
import ssl 
import urllib.request, urllib.error, urllib.parse
import sqlite3
import json
import time
import sys
# create
conn = sqlite3.connect('fri.sqlite')
cur = conn.cursor()

cur.execute('CREATE TABLE IF NOT EXISTS Position (address TEXT, geodata TEXT)')

# ctx
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

# api
api_key = 'AIzaSyDS9ADEfzGK_vvZbiWKLU_Bh5-FcOvyUV4'
if api_key == False: 
    api_key = 42
    serviceurl = 'http://py4e-data.dr-chuck.net/json?'
else: 
    serviceurl = 'https://maps.googleapis.com/maps/api/geocode/json?'
# open file
fh = open('where.data')
count = 0
# loop
for line in fh:
    if count >200: 
        break
# make sure geodata is not existing in table
    address = line.strip()
    cur.execute('SELECT geodata FROM Position WHERE address = ?', (memoryview(address.encode()), ))
    try:
        data = cur.fetchone()[0]
        print('Found in database', address)
        continue
    except:
        pass
    
    parms = dict()
    parms['address'] = address
    if api_key is not False:
        parms['key'] = api_key
    url = serviceurl + urllib.parse.urlencode(parms)
    connection = urllib.request.urlopen(url, context = ctx)
    data = connection.read().decode() 
    print('Retrieved', len(data), 'characters', data[:20].replace('\n', ''))
    count = count + 1
    
    try:
        js = json.loads(data)
    except:
        print(data)
        continue
    if 'status' not in js or (js['status'] != 'OK' and js['status'] == 'ZERO_RESULTS'):
        print(data)
        break
    cur.execute('INSERT OR IGNORE INTO Position (address, geodata) VALUES (?,?)',
               (memoryview(address.encode()),memoryview(data.encode())))
    conn.commit()
    if count %10 == 0:
        time.sleep(5)
print('Run geodump.py to read the data from the database\so you visualize it on a map')
    
# if not make url by  use the serviceurl + urllib.parse.urlencode
# urllib open, read, decode
# loading using json
# search around jsonv(before setting some break criteria)
# insert address and geodata into the table using 
# memoryview(address.encode()), memoryview(encode.encode())
# Out:
# Found in database AGH University of Science and Technology
# Found in database Academy of Fine Arts Warsaw Poland
# Found in database American University in Cairo
# Found in database Arizona State University
# Found in database Athens Information Technology
# Found in database BITS Pilani
# Found in database Babcock University
# Found in database Banaras Hindu University
# Found in database Bangalore University
# Found in database Baylor University
# Found in database Beijing normal university
# Found in database Belarusian State University
# Found in database Belgrade University
# Found in database Beloit College
# Found in database Belorussian State University
# Found in database Ben Gurion University
# Found in database Bharthidasan University
# Found in database Boston University
# Found in database California Polytechnic State University of San Luis Obispo
# Found in database California State University San Bernardino
# Found in database City of Westminster College
# Found in database Columbia University
# Found in database Cranfield University
# Found in database Czech Technical University in Prague
# Found in database Dartmouth
# Found in database De Anza College
# Found in database Distant University of Hagen
# Found in database Dnipropetrovsk National University
# Found in database Dokuz Eylul University
# Found in database Drexel
# Found in database Drexel University and University of Texas at Austin
# Found in database Duke University
# Found in database EM Lyon
# Found in database Ecole centrale de PARIS
# Found in database Elon University
# Found in database Erhvervsakademi Sydvest
# Found in database Escuela Superior Politecnica del Litoral
# Found in database Fachhochschule Dusseldorf
# Found in database Fachhochschule FH Salzburg
# Found in database Faculdade de Tecnologia do Estado de Sao Paulo
# Retrieved 2116 characters {   "results" : [
# Retrieved 2135 characters {   "results" : [
# Retrieved 2243 characters {   "results" : [
# Retrieved 2128 characters {   "results" : [
# Retrieved 2286 characters {   "results" : [
# Retrieved 2014 characters {   "results" : [
# Retrieved 2314 characters {   "results" : [
# Retrieved 2267 characters {   "results" : [
# Retrieved 1978 characters {   "results" : [
# Retrieved 1752 characters {   "results" : [
# Retrieved 2099 characters {   "results" : [
# Retrieved 1801 characters {   "results" : [
# Retrieved 1248 characters {   "results" : [
# Retrieved 2378 characters {   "results" : [
# Retrieved 2007 characters {   "results" : [
# Retrieved 2089 characters {   "results" : [
# Retrieved 2312 characters {   "results" : [
# Retrieved 1832 characters {   "results" : [
# Retrieved 2268 characters {   "results" : [
# Retrieved 2467 characters {   "results" : [
# Retrieved 4485 characters {   "results" : [
# Retrieved 1817 characters {   "results" : [
# Retrieved 1653 characters {   "results" : [
# Retrieved 2312 characters {   "results" : [
# Retrieved 2312 characters {   "results" : [
# Retrieved 2143 characters {   "results" : [
# Retrieved 2146 characters {   "results" : [
# Retrieved 2209 characters {   "results" : [
# Retrieved 2378 characters {   "results" : [
# Retrieved 2175 characters {   "results" : [
# Retrieved 2342 characters {   "results" : [
# Retrieved 2410 characters {   "results" : [
# Retrieved 1624 characters {   "results" : [
# Retrieved 1260 characters {   "results" : [
# Retrieved 1807 characters {   "results" : [
# Retrieved 52 characters {   "results" : [],
# {
#    "results" : [],
#    "status" : "ZERO_RESULTS"
# }
#
# Run geodump.py to read the data from the database\so you visualize it on a map

# %%
# clean the data assignment
# import
import sqlite3
import json
import codecs
# connect with database
conn = sqlite3.connect('geodata.sqlite')
cur = conn.cursor()
# lock on target
cur.execute('SELECT * FROM Locations')
# use codecs open where.js as utf-8
fhand = codecs.open('where.js', 'w', 'utf-8')
# modified the content 
fhand.write('myData = [\n')
count = 0
# loop through the data base and decode the geodata
for row in cur:
    data = str(row[1].decode())
    try:
        js = json.loads(str(data))
    except: continue    
    if not('status' in js and js['status'] == 'OK') : continue
        # obtained lat and lng and where   
    lat = js['results'][0]['geometry']['location']['lat']
    lng = js['results'][0]['geometry']['location']['lng']
    if lat == 0 or lng == 0: continue
    where = js['results'][0]['formatted_address']
    where = where.replace("'", "")
    try :
        print(where, lat, lng)
            
        count = count + 1
        if count > 1: fhand.write(",\n")
        output = "["+str(lat)+","+str(lng)+",'"+where+"']"
        fhand.write(output)
    except:
        continue
fhand.write('\n];\n')
# Out:
# aleja Adama Mickiewicza 30, 30-059 Kraków, Poland 50.06688579999999 19.9136192
# Krakowskie Przedmieście 5, 00-068 Warszawa, Poland 52.2394019 21.0150792
# AUC Avenue، 11835, Egypt 30.018923 31.499674
# Tempe, AZ 85281, USA 33.4242399 -111.9280527
# 300, 2500 Daniells Bridge Rd, Athens, GA 30606, USA 33.9094132 -83.4603953
# Pilani, Rajasthan 333031, India 28.3588163 75.58802039999999
# Ilishan-Remo, Nigeria 6.8946472 3.7174267
# Ajagara, Varanasi, Uttar Pradesh 221005, India 25.2677203 82.99125819999999
# Gnana Bharathi Campus, Gnana Bharathi Main Rd, Teachers Colony, Nagarbhavi, Bengaluru, Karnataka 560056, India 12.9527314 77.5157387
# 1301 S University Parks Dr, Waco, TX 76706, USA 31.5497007 -97.1143046
# 19 Xinjiekou Outer St, BeiTaiPingZhuang, Haidian Qu, Beijing Shi, China, 100875 39.9619537 116.3662615
# Prospekt Nezavisimosti 4, Minsk, Belarus 53.8938988 27.5460609
# Studentski trg 1, Beograd, Serbia 44.8184339 20.4575676
# 700 College St, Beloit, WI 53511, USA 42.5030333 -89.0309048
# Prospekt Nezavisimosti 4, Minsk, Belarus 53.8938988 27.5460609
# שד בן-גוריון 1, באר שבע, Israel 31.262218 34.801461
# Palkalaiperur, Tiruchirappalli, Tamil Nadu 620024, India 10.6779085 78.74454879999999
# Boston, MA 02215, USA 42.3504997 -71.1053991
# San Luis Obispo, CA 93407, USA 35.3050053 -120.6624942
# 5500 University Pkwy, San Bernardino, CA 92407, USA 34.1821786 -117.3235324
# 25 Paddington Green, London W2 1NB, UK 51.5210038 -0.1746353
# 116th St & Broadway, New York, NY 10027, United States 40.8075355 -73.9625727
# College Rd, Wharley End, Bedford MK43 0AL, UK 52.0741818 -0.6278123
# Zikova 1903/4, 166 36 Praha 6, Czechia 50.1030364 14.3912841
# Hanover, NH 03755, USA 43.7044406 -72.2886935
# 21250 Stevens Creek Blvd, Cupertino, CA 95014, USA 37.3201481 -122.0453953
# 600 11th St S, Moorhead, MN 56563, USA 46.8677579 -96.7623133
# Haharina Ave, 72, Dnipropetrovsk, Dnipropetrovska oblast, Ukraine, 49000 48.4331922 35.0427966
# Kültür Mahallesi, Cumhuriyet Blv No:144, 35220 Konak/İzmir, Turkey 38.4306911 27.1369201
# 3141 Chestnut St, Philadelphia, PA 19104, USA 39.9566127 -75.18994409999999
# Austin, TX 78712, USA 30.2849185 -97.7340567
# Durham, NC 27708, USA 36.0014258 -78.9382286
# 23 Avenue Guy de Collongue, 69130 Écully, France 45.786447 4.764139000000001
# 3 Rue Joliot Curie, 91190 Gif-sur-Yvette, France 48.708759 2.164006
# 50 Campus Drive, Elon, NC 27244, USA 36.1027527 -79.50235669999999
# Spangsbjerg Kirkevej 103, 6700 Esbjerg, Denmark 55.48843069999999 8.4467103
# Vía Perimetral 5, Guayaquil, Ecuador -2.1481458 -79.9644885
# Münsterstraße 156, 40476 Düsseldorf, Germany 51.2468622 6.791686899999999
# Urstein Süd 1, 5412 Puch bei Hallein, Austria 47.72336 13.0871409
# Av. Pereira Barreto, 400 - Baeta Neves, São Bernardo do Campo - SP, 09751-000, Brazil -23.6958721 -46.54702839999999
# Trg Dositeja Obradovića 6, Novi Sad 106314, Serbia 45.2461012 19.8516968
# 2350 NY-110, Farmingdale, NY 11735, USA 40.7529512 -73.4267093
# Av. Pres. Antônio Carlos, 6627 - Pampulha, Belo Horizonte - MG, 31270-901, Brazil -19.8690878 -43.9663841
# 777 Glades Rd, Boca Raton, FL 33434, USA 26.3750234 -80.1008751
# 40 University Dr, Rindge, NH 03461, USA 42.7793667 -72.0560856
# Jalukbari, Guwahati, Assam 781014, India 26.1546284 91.66469889999999
# 4400 University Dr, Fairfax, VA 22030, USA 38.8314936 -77.3114889
# 600 New Jersey Ave NW, Washington, DC 20001, USA 38.8977953 -77.0129087
# Atlanta, GA 30302, USA 33.753068 -84.38528190000001
# Grandville, MI, USA 42.9097484 -85.7630885
# Andreas Vesaliusstraat 13, 3000 Leuven, Belgium 50.8748769 4.7077753
# 1 Đại Cồ Việt, Bách Khoa, Hai Bà Trưng, Hà Nội, Vietnam 21.0055546 105.8434628
# Jerusalem 31.7945578 35.2414009
# DLF Building, Professor CR Rao Rd, Gachibowli, Hyderabad, Telangana 500032, India 17.4452358 78.3492765
# Kalyanpur, Kanpur, Uttar Pradesh 208016, India 26.5123388 80.2329
# Raja 4, 12616 Tallinn, Estonia 59.3954769 24.6643815
# 107 S Indiana Ave, Bloomington, IN 47405, USA 39.1670139 -86.51855379999999
# Santa Croce, 191, 30135 Venezia VE, Italy 45.4377672 12.321807
# 10 W 35th St, Chicago, IL 60616, USA 41.8348731 -87.6270059
# 1215 Houbolt Rd, Joliet, IL 60431, USA 41.5002857 -88.1687295

# %%
# Out:
#   File "<ipython-input-27-2cb430044150>", line 1
#     <html>
#     ^
# SyntaxError: invalid syntax
