# %%
# crawling google map 
import urllib.request, urllib.parse, urllib.error
import json
import ssl
api_key = 'AIzaSyDS9ADEfzGK_vvZbiWKLU_Bh5-FcOvyUV4'
if api_key is False:
    api_key = 42
    serviceurl = 'http://py4e-data.dr-chuck.net/json?'
else:
    serviceurl = 'https://maps.googleapis.com/maps/api/geocode/json?'

ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

# continuely input location
while True:
    address = input('Enter location: ')
    if len(address) < 1: break
# concatenate a url    
    parms = dict()
    parms['address'] = address
    if api_key is not False: parms['key'] = api_key
    url = serviceurl + urllib.parse.urlencode(parms)
    
    print('Retrieving', url)
# parse url
    uh = urllib.request.urlopen(url, context = ctx)
    data = uh.read().decode()
    print('Retrieved', len(data), 'characters')
    
    try:
        js = json.loads(data)
    except:
        js = None
    
    if not js or 'status' not in js or js['status'] != 'OK':
        print('==== Failure To Retrieve ====')
        print(data)
        continue
    
    lat = js["results"][0]["geometry"]["location"]["lat"]
    lng = js["results"][0]["geometry"]["location"]["lng"]
    location = js['results'][0]['formatted_address']
    print(location)

# %%
import urllib.request, urllib.parse, urllib.error
import augment
import ssl

# https://apps.twitter.com/
# Create App and get the four strings, put them in hidden.py

print('* Calling Twitter...')
url = augment('https://api.twitter.com/1.1/statuses/user_timeline.json',
              {'screen_name': 'drchuck', 'count': '2'})
print(url)

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

connection = urllib.request.urlopen(url, context=ctx)
data = connection.read()
print(data)

print ('======================================')
headers = dict(connection.getheaders())
print(headers)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-4dbba39761ec> in <module>()
#       1 import urllib.request, urllib.parse, urllib.error
# ----> 2 import augment
#       3 import ssl
#       4
#       5 # https://apps.twitter.com/
#
# ModuleNotFoundError: No module named 'augment'

# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
import twitter_credentials
import time
c

access_token = '1048314513668411393-gmqLc2d2MEfmszTdLgubK0fG0r3vQY '
access_token_secret = 'R6XcStzWJdz9QibcfQ7mrY7Kkf4BTAND1SQ3Tk8NUCk1y'
consumers_key = 'B0pn6CnbRfohPISEyraaLw5xd'
consumers_secret = 'HWMsvM3XcPn0uxUondQMBAlkstt6OE9DCHS7cARojOeHoD7Vjj'

class StdoutListener(StreamListener):
    
    def on_data(self,data):
        try:
            print(data)
            savefile = open("d:\\twitters")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-cea6314321e3> in <module>()
#       1 import json
#       2 data = [ "Glenn", "Sally", "Jen"]
# ----> 3 info = json.loads(data)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     339     else:
#     340         if not isinstance(s, (bytes, bytearray)):
# --> 341             raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     342                             f'not {s.__class__.__name__}')
#     343         s = s.decode(detect_encoding(s), 'surrogatepass')
#
# TypeError: the JSON object must be str, bytes or bytearray, not list

# %%
import urllib.request, urllib.parse, urllib.error
import json
import ssl

#api_key = False
# If you have a Google Places API key, enter it here
api_key = 'AIzaSyDS9ADEfzGK_vvZbiWKLU_Bh5-FcOvyUV4'
# https://developers.google.com/maps/documentation/geocoding/intro

if api_key is False:
    api_key = 42
    serviceurl = 'http://py4e-data.dr-chuck.net/json?'
else :
    serviceurl = 'https://maps.googleapis.com/maps/api/geocode/json?'

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

while True:
    address = input('Enter location: ')
    if len(address) < 1: break

    parms = dict()
    parms['address'] = address
    if api_key is not False: parms['key'] = api_key
    url = serviceurl + urllib.parse.urlencode(parms)

    print('Retrieving', url)
    uh = urllib.request.urlopen(url, context=ctx)
    data = uh.read().decode()
    print('Retrieved', len(data), 'characters')

    try:
        js = json.loads(data)
    except:
        js = None

    if not js or 'status' not in js or js['status'] != 'OK':
        print('==== Failure To Retrieve ====')
        print(data)
        continue

    print(json.dumps(js, indent=4))

    lat = js['results'][0]['geometry']['location']['lat']
    lng = js['results'][0]['geometry']['location']['lng']
    print('lat', lat, 'lng', lng)
    location = js['results'][0]['formatted_address']
    print(location)
# Out:
# Enter location: kelvin court
# Retrieving https://maps.googleapis.com/maps/api/geocode/json?address=kelvin+court&key=AIzaSyDS9ADEfzGK_vvZbiWKLU_Bh5-FcOvyUV4
# Retrieved 2304 characters
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "2552",
#                     "short_name": "2552",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "long_name": "Kelvin Avenue",
#                     "short_name": "Kelvin Ave",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Irvine Business Complex",
#                     "short_name": "Irvine Business Complex",
#                     "types": [
#                         "neighborhood",
#                         "political"
# ...
